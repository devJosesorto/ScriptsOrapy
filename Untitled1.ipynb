# %%
from rich.table import Table
from rich.console import Console
from rich.theme import Theme
import cx_Oracle

# Definir un tema con bordes para la tabla
custom_theme = Theme({
    "rule": "bright_black",
    "border": "bright_black",
    "table": "bright_black",
    "header": "bold bright_white",
})

# Crear una instancia de la consola con el tema personalizado
console = Console(theme=custom_theme)

# Crear una tabla y agregar columnas
table = Table(show_header=True, header_style="bold magenta")
table.add_column("stock", style="cyan", justify="left")
table.add_column("cantidad", style="cyan", justify="left")
table.add_column("Nombre", style="cyan", justify="left")

dsn = cx_Oracle.makedsn('localhost', 1521, service_name='XE')
connection = cx_Oracle.connect(user='C##JSORTO', password='72776400', dsn=dsn)

cursor = connection.cursor()

sql = '''SELECT * FROM compras'''
cursor.execute(sql)
datos = cursor.fetchall()
for x in datos:
    table.add_row(str(x[0]), str(x[1]), str(x[2]))  # Convertir cada elemento a cadena antes de agregarlo a la fila
console.print(table)
connection.close()
# Out:
# ┏━━━━━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ stock ┃ cantidad ┃ Nombre                               ┃
# ┡━━━━━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ 3     │ 51       │ Artículos de papelería               │
# │ 5     │ 75       │ Juguetes para niños                  │
# │ 7     │ 80       │ Productos de belleza                 │
# │ 9     │ 40       │ Alimentos y comestibles              │
# │ 11    │ 91       │ Artículos de jardinería              │
# │ 13    │ 60       │ Productos de limpieza                │
# │ 15    │ 46       │ Accesorios deportivos                │
# │ 17    │ 75       │ Material de arte                     │
# │ 19    │ 55       │ Bicicletas y accesorios              │
# │ 22    │ 36       │ Material de oficina                  │
# │ 24    │ 81       │ Accesorios para la playa             │
# │ 27    │ 45       │ Productos para el cabello            │
# │ 29    │ 70       │ Artículos para el hogar              │
# ...
